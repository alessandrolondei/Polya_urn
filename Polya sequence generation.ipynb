# %%
from Polya import PolyaUrn, load_polya
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Polya parameters

# %%
nu = 2
rho = 3
eta = 1.0
entropy_base = 2
seq_len=10000

# %% [markdown]
# ### Instantiating Polya object

# %%
p = PolyaUrn(rho=rho, nu=nu, eta=eta, entropy_base=entropy_base)

# %% [markdown]
# ### Polya's sequence

# %%
p.get_sequence(seq_len=seq_len)

# %%
p.seq
# Out:
# array([ 4,  4,  4, ..., 27, 12,  4])

# %% [markdown]
# Max element (color) in Polya sequence

# %%
p.seq.max()
# Out:
# 939

# %% [markdown]
# ### Print Polya Urn info

# %%
print(p)
# Out:
# Rho: 3
# Nu: 2
# Eta: 1.0
# # balls: 31010
# # internal colors: 1010
# # novelties: 335
# Polya sequence length: 10000
# Sequence entropy not present
# Sequence distributions not present
# Sequence seen distributions not present

# %% [markdown]
# ### Calculate extras (entropies and distributions)

# %%
p.get_entropy_and_distributions()

# %% [markdown]
# ### Plotting entropies

# %%
plt.plot(p.extras['seq_entropy'], label='Urn Entropy')
plt.plot(p.extras['seq_seen_entropy'], label='Sequence Entropy')
_ = plt.legend(loc='best')

# %% [markdown]
# ### Plotting distributions at different steps

# %%
steps = [0, 2, 10, 30, 60, 100]
width = 0.35
for step in steps:
    plt.figure(figsize=(20,6))
    ind = np.arange(p.extras['seq_distributions'][step].shape[0])
    plt.bar(ind, p.extras['seq_distributions'][step], width, label='Urn distribution at step '+str(step))
    plt.bar(ind+width, p.extras['seq_seen_distributions'][step], width, label='Sequence distribution at step '+str(step))
    _ = plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Zipf's and Heaps' distributions

# %%
zipf = p.zipf()
plt.loglog(zipf)
plt.title('Zipf\'s distribution')
plt.show()

# %%
heaps = p.heaps()
plt.loglog(heaps)
plt.title('Heaps\' distribution')
plt.show()

# %% [markdown]
# ### Shuffling sequence elements

# %%
new_seq = p.seq_color_shuffling(max_color=100000)

# %%
print('Real sequence:', p.seq[:30], '\n')
print('Shuffled sequence:', new_seq[:30])
# Out:
# Real sequence: [ 4  4  4  4  4  0  6  4  4 12  4  4  4  4 12 12 12  4  4  4  4  4 12  0
#   4  0  4  4 12 12]
#
# Shuffled sequence: [56613 56613 56613 56613 56613 71326 18860 56613 56613 49051 56613 56613
#  56613 56613 49051 49051 49051 56613 56613 56613 56613 56613 49051 71326
#  56613 71326 56613 56613 49051 49051]

# %% [markdown]
# ### Compacting sequence

# %%
comp_seq = p.seq_compacting()

# %%
print('Real sequence:', p.seq[:30], '\n')
print('Compacted sequence:', comp_seq[:30])
# Out:
# Real sequence: [ 4  4  4  4  4  0  6  4  4 12  4  4  4  4 12 12 12  4  4  4  4  4 12  0
#   4  0  4  4 12 12]
#
# Compacted sequence: [ 4  4  4  4  4  0  6  4  4 12  4  4  4  4 12 12 12  4  4  4  4  4 12  0
#   4  0  4  4 12 12]

# %% [markdown]
# ### Saving Polya

# %%
p.save()

# %% [markdown]
# ### Saving extras (entropies and distributions)

# %%
p.save_extras()

# %% [markdown]
# ### Load Polya without extras

# %%
p1 = load_polya('./polya_seq/polya_urn_len_10000_novelties_335_nu2_rho3_eta1.pkl')

# %%
print(p1)
# Out:
# Rho: 3
# Nu: 2
# Eta: 1.0
# # balls: 31010
# # internal colors: 1010
# # novelties: 335
# Polya sequence length: 10000
# Sequence entropy not present
# Sequence distributions not present
# Sequence seen distributions not present

# %% [markdown]
# ### Loading Polya extras

# %%
p1.load_extras('./polya_seq/polya_urn_len_10000_novelties_335_nu2_rho3_eta1_extras.pkl')

# %%
print(p1)
# Out:
# Rho: 3
# Nu: 2
# Eta: 1.0
# # balls: 31010
# # internal colors: 1010
# # novelties: 335
# Polya sequence length: 10000
# Sequence entropy done
# Sequence distributions done
# Sequence seen distributions done
